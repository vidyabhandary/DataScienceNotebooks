# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-pandas,-numpy,-pprint,-and-the-pyreadr-package" data-toc-modified-id="Load-pandas,-numpy,-pprint,-and-the-pyreadr-package-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load pandas, numpy, pprint, and the pyreadr package</a></span></li><li><span><a href="#Get-the-R-data" data-toc-modified-id="Get-the-R-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Get the R data</a></span></li><li><span><a href="#Set-up-dictionaries-for-value-labels-and-column-headings" data-toc-modified-id="Set-up-dictionaries-for-value-labels-and-column-headings-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Set up dictionaries for value labels and column headings</a></span></li><li><span><a href="#Set-value-labels-and-missing-values,-and-change-selected-columns-to-category-data-type" data-toc-modified-id="Set-value-labels-and-missing-values,-and-change-selected-columns-to-category-data-type-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Set value labels and missing values, and change selected columns to category data type</a></span></li><li><span><a href="#Set-meaningful-column-headings" data-toc-modified-id="Set-meaningful-column-headings-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Set meaningful column headings</a></span></li></ul></div>

# %% [markdown]
# # Load pandas, numpy, pprint, and the pyreadr package

# %%
# import pandas, numpy, and pyreadr
import pandas as pd
import numpy as np
import pyreadr
import pprint

# %%
# pd.set_option('display.width', 72)
# pd.set_option('display.max_columns', 5)
# pd.set_option('display.max_rows', 25)

# %%
import watermark
# %load_ext watermark

# %watermark -n -v -g -iv
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.7.9
# IPython version      : 7.20.0
#
# Git hash: 746d437b191d4078c99dea0483d16bf95caddc02
#
# numpy    : 1.19.2
# json     : 2.0.9
# pandas   : 1.2.1
# watermark: 2.1.0
# pyreadr  : 0.4.0

# %% [markdown]
# # Get the R data

# %%
nls97r = pyreadr.read_r('data/nls97.rds')[None]

# %%
nls97r.dtypes
# Out:
# R0000100    int32
# R0536300    int32
# R0536401    int32
# R0536402    int32
# R1235800    int32
# R1482600    int32
# R9793800    int32
# R9793900    int32
# R9871900    int32
# R9872000    int32
# R9872200    int32
# R9872400    int32
# S8646900    int32
# S8647000    int32
# S8647100    int32
# S8647200    int32
# S8647300    int32
# S8647400    int32
# S8647500    int32
# S8647600    int32
# S8647700    int32
# S8647800    int32
# T6651700    int32
# U1836800    int32
# U1836900    int32
# U1837000    int32
# U1837100    int32
# U1837200    int32
# U1837300    int32
# U1845400    int32
# U1852400    int32
# U1852600    int32
# U1852700    int32
# U2166200    int32
# U2166300    int32
# U2166400    int32
# U2166500    int32
# U2857300    int32
# U2962800    int32
# U2962900    int32
# U2963000    int32
# Z9063900    int32
# dtype: object

# %%
nls97r.head(10)
# Out:
#    R0000100  R0536300  R0536401  R0536402  R1235800  R1482600  R9793800  \
# 0         1         2         9      1981         1         4       350
# 1         2         1         7      1982         1         2       460
# 2         3         2         9      1983         1         2        -4
# 3         4         2         2      1981         1         2        -4
# 4         5         1        10      1982         1         2        -4
# 5         6         2         1      1982         1         2        -4
# 6         7         1         4      1983         1         2        -4
# 7         8         2         6      1981         1         4       620
# 8         9         1        10      1982         1         4       380
# 9        10         1         3      1984         1         4       600
#
#    R9793900  R9871900  R9872000  ...  U1852700  U2166200  U2166300  U2166400  \
# 0       470       309       310  ...        -5        -5        -5        -5
# ...

# %% [markdown]
# # Set up dictionaries for value labels and column headings

# %%
with open('data/nlscodes.txt', 'r') as reader:
    setvalues = eval(reader.read())

# %%
pprint.pprint(setvalues)
# Out:
# {'R0536300': {0.0: 'No Information', 1.0: 'Male', 2.0: 'Female'},
#  'R1235800': {0.0: 'Oversample', 1.0: 'Cross-sectional'},
#  'S8646900': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647000': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647100': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647200': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647300': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
#               3.0: '3. Probably not',
#               4.0: '4. Definitely not'},
#  'S8647400': {1.0: '1. Definitely',
#               2.0: '2. Probably ',
# ...

# %% [markdown]
# # Set value labels and missing values, and change selected columns to category data type

# %%
nls97r.replace(setvalues, inplace=True)
nls97r.head()
# Out:
#    R0000100 R0536300  R0536401  R0536402         R1235800  R1482600  R9793800  \
# 0         1   Female         9      1981  Cross-sectional         4       350
# 1         2     Male         7      1982  Cross-sectional         2       460
# 2         3   Female         9      1983  Cross-sectional         2        -4
# 3         4   Female         2      1981  Cross-sectional         2        -4
# 4         5     Male        10      1982  Cross-sectional         2        -4
#
#    R9793900  R9871900  R9872000  ...  U1852700  U2166200 U2166300 U2166400  \
# 0       470       309       310  ...        -5        -5       -5       -5
# 1       440       217       280  ...        -4        -4       -4       -4
# 2        -4        -4        -4  ...         0        -4       -4       -4
# 3        -4       253       216  ...         1        -4       -4       -4
# 4        -4       243       235  ...         0        -4       -4       -4
#
# ...

# %%
nls97r.replace(list(range(-9, 0)), np.nan, inplace=True)

# %%
for col in nls97r[[k for k in setvalues]].columns:
    nls97r[col] = nls97r[col].astype('category')

# %%
nls97r.dtypes
# Out:
# R0000100     float64
# R0536300    category
# R0536401     float64
# R0536402     float64
# R1235800    category
# R1482600     float64
# R9793800     float64
# R9793900     float64
# R9871900     float64
# R9872000     float64
# R9872200     float64
# R9872400     float64
# S8646900    category
# S8647000    category
# S8647100    category
# S8647200    category
# S8647300    category
# S8647400    category
# S8647500    category
# S8647600    category
# S8647700    category
# S8647800    category
# T6651700     float64
# U1836800    category
# U1836900    category
# U1837000    category
# U1837100    category
# U1837200    category
# U1837300    category
# U1845400    category
# U1852400    category
# U1852600     float64
# U1852700     float64
# U2166200    category
# U2166300    category
# U2166400    category
# U2166500    category
# U2857300    category
# U2962800    category
# U2962900    category
# U2963000     float64
# Z9063900     float64
# dtype: object

# %% [markdown]
# # Set meaningful column headings

# %%
newcols = ['personid','gender','birthmonth','birthyear',
  'sampletype',  'category','satverbal','satmath',
  'gpaoverall','gpaeng','gpamath','gpascience','govjobs',
  'govprices','govhealth','goveld','govind','govunemp',
  'govinc','govcollege','govhousing','govenvironment',
  'bacredits','coltype1','coltype2','coltype3','coltype4',
  'coltype5','coltype6','highestgrade','maritalstatus',
  'childnumhome','childnumaway','degreecol1',
  'degreecol2','degreecol3','degreecol4','wageincome',
  'weeklyhrscomputer','weeklyhrstv',
  'nightlyhrssleep','weeksworkedlastyear']

# %%
nls97r.columns = newcols

# %%
nls97r.head()
# Out:
#    personid  gender  birthmonth  birthyear       sampletype  category  \
# 0       1.0  Female         9.0     1981.0  Cross-sectional       4.0
# 1       2.0    Male         7.0     1982.0  Cross-sectional       2.0
# 2       3.0  Female         9.0     1983.0  Cross-sectional       2.0
# 3       4.0  Female         2.0     1981.0  Cross-sectional       2.0
# 4       5.0    Male        10.0     1982.0  Cross-sectional       2.0
#
#    satverbal  satmath  gpaoverall  gpaeng  ...  childnumaway  degreecol1  \
# 0      350.0    470.0       309.0   310.0  ...           NaN         NaN
# 1      460.0    440.0       217.0   280.0  ...           NaN         NaN
# 2        NaN      NaN         NaN     NaN  ...           0.0         NaN
# 3        NaN      NaN       253.0   216.0  ...           1.0         NaN
# 4        NaN      NaN       243.0   235.0  ...           0.0         NaN
#
#   degreecol2 degreecol3 degreecol4 wageincome           weeklyhrscomputer  \
# ...
